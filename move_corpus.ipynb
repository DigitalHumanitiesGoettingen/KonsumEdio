# %%
import os

# %%
path = "/home/jakob/Johanna/Masterarbeit/temp"

dir_names = [x[0] for x in os.walk(path)]

for dirname in dir_names[1:]:
    for filename in os.listdir(dirname):
        os.rename(dirname + "/" + filename, dirname + "/" + dirname[-19:]+"_"+filename)
        #print(dirname+"/"+filename)

# %%
path = "/home/jakob/Johanna/Masterarbeit/temp/"
dir_names = [x[0] for x in os.walk(path)]

for dirname in dir_names[1:]:
    for filename in os.listdir(dirname):
        os.rename(dirname+"/"+filename, path+filename)

# %%
import json
path = "/home/jakob/Johanna/Masterarbeit/temp/"
filedir = dict(zip([x+293 for x in range(len(os.listdir(path)))], os.listdir(path)))
with open('/home/jakob/Johanna/Masterarbeit/corpus/data_1.json', 'w') as fp:
    json.dump(filedir, fp, sort_keys=True, indent=4)
print(filedir)
# Out:
# {293: 'sturm1910_1911_0099_0_14.png', 294: 'sturm1910_1911_0180_1_0.png', 295: 'sturm1910_1911_0165_2_9.png', 296: 'sturm1910_1911_0189_2_36.png', 297: 'sturm1910_1911_0190_0_0.png', 298: 'sturm1910_1911_0116_0_4.png', 299: 'sturm1910_1911_0173_2_2.png', 300: 'sturm1910_1911_0099_0_7.png', 301: 'sturm1910_1911_0099_0_3.png', 302: 'sturm1910_1911_0189_2_17.png', 303: 'sturm1910_1911_0115_0_3.png', 304: 'sturm1910_1911_0141_0_1.png', 305: 'sturm1910_1911_0165_1_7.png', 306: 'sturm1910_1911_0150_0_2.png', 307: 'sturm1910_1911_0158_0_4.png', 308: 'sturm1910_1911_0133_0_3.png', 309: 'sturm1910_1911_0157_0_8.png', 310: 'sturm1910_1911_0117_0_8.png', 311: 'sturm1910_1911_0134_4_0.png', 312: 'sturm1910_1911_0157_0_4.png', 313: 'sturm1910_1911_0099_0_2.png', 314: 'sturm1910_1911_0108_3_13.png', 315: 'sturm1910_1911_0100_0_8.png', 316: 'sturm1910_1911_0173_0_1.png', 317: 'sturm1910_1911_0156_2_3.png', 318: 'sturm1910_1911_0132_2_6.png', 319: 'sturm1910_1911_0098_1_7.png', 320: 'sturm1910_1911_
# ...
