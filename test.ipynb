# %%
import numpy as np
import matplotlib.pyplot as plt

from skimage import measure
from skimage.io import imread, imsave
from skimage.color import rgb2gray
from skimage.filters import threshold_otsu


# Construct some test data
r = imread("../input/prep/bin/sturm1910_1911_0043.png")

# Find contours at a constant value of 0.8
contours = measure.find_contours(r, 0.9)

# Display the image and plot all contours found
fig, ax = plt.subplots()
ax.imshow(r, cmap=plt.cm.gray)

for contour in contours:
    ax.plot(contour[:, 1], contour[:, 0], linewidth=2)

ax.axis('image')
ax.set_xticks([])
ax.set_yticks([])
plt.show()

# %%
from skimage.data import astronaut
from skimage.filters import gaussian
image = imread("../output/test/sturm1910_1911_0043.jpg")
grayscale = rgb2gray(image)
thresh = threshold_otsu(grayscale)
bin_image = grayscale > thresh

fig, ax = plt.subplots()
ax.imshow(bin_image)

imsave("../output/test/test.png", bin_image)
# Out:
# /home/jakob/anaconda3/envs/JohannaProbiert/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: ../output/test/test.png is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Find contours at a constant value of 0.8
contours = measure.find_contours(bin_image, 0.3)

# Display the image and plot all contours found
fig, ax = plt.subplots()
ax.imshow(r, cmap=plt.cm.gray)

for contour in contours:
    ax.plot(contour[:, 1], contour[:, 0], linewidth=2)

ax.axis('image')
ax.set_xticks([])
ax.set_yticks([])
plt.show()
